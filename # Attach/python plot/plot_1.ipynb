# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1366, 1470, 1545, 1550, 1590, 1600, 1602, 1720, 1839]
y = [0.42, 0.87, 2.96, 3.33, 4.19, 3.50, 2.96, 0.72, 0.42]

# %%
plt.plot(x, y)
plt.xlabel('f / KHZ')
plt.ylabel('U_opp / V')
plt.show()
